# %%
from janome.tokenizer import Tokenizer

# %%
t = Tokenizer()
markov = {}

# %%
kashi = open('./data/kashi.txt', 'r').read()
#kashi = kashi.decode('utf_8')
words = t.tokenize(kashi)

# %%
for i in words:
    print(i)
# Out:
# 気付か	動詞,自立,*,*,五段・カ行イ音便,未然形,気付く,キヅカ,キズカ
# ず	助動詞,*,*,*,特殊・ヌ,連用ニ接続,ぬ,ズ,ズ
# また	接続詞,*,*,*,*,*,また,マタ,マタ
# 誰	名詞,代名詞,一般,*,*,*,誰,ダレ,ダレ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 困ら	動詞,自立,*,*,五段・ラ行,未然形,困る,コマラ,コマラ
# せ	動詞,接尾,*,*,一段,連用形,せる,セ,セ
# 傷つけ	動詞,自立,*,*,一段,連用形,傷つける,キズツケ,キズツケ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# でしょ	助動詞,*,*,*,特殊・デス,未然形,です,デショ,デショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# ?	名詞,サ変接続,*,*,*,*,?,*,*
# 探し	動詞,自立,*,*,五段・サ行,連用形,探す,サガシ,サガシ
# て	動詞,非自立,*,*,一段,連用形,てる,テ,テ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# モノ	名詞,一般,*,*,*,*,モノ,モノ,モノ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# とらわれ	動詞,自立,*,*,一段,連用形,とらわれる,トラワレ,トラワレ
# 我	名詞,一般,*,*,*,*,我,ワガ,ワガ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 忘れ	動詞,自立,*,*,一段,連用形,忘れる,ワスレ,ワスレ
# て	動詞,非自立,*,*,一段,連用形,てる,テ,テ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# でしょ	助動詞,*,*,*,特殊・デス,未然形,です,デショ,デショ
# う	助動詞,*,*,*,不変化型,基本形,う,ウ,ウ
# …	記号,一般,*,*,*,*,…,…,…
# あの	連体詞,*,*,*,*,*,あの,アノ,アノ
# 花	名詞,一般,*,*,*,*,花,ハナ,ハナ
# の	助詞,格助詞,一般,*,*,*,の,ノ,ノ
# 舞っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,舞う,マッ,マッ
# て	動詞,非自立,*,*,一段,連用形,てる,テ,テ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# ...

# %%
# 辞書を生成
def make_dic(words):
    tmp = ["@"]
    dic = {}
    for i in words:
        word = i.surface
        #if word == "" or word == "\r\n" or word == "\n": continue
        tmp.append(word)
        if len(tmp) < 3: continue
        if len(tmp) > 3: tmp = tmp[1:]
        set_word3(dic, tmp)
        if word == "\n":
            tmp = ["@"]
            continue
    return dic
